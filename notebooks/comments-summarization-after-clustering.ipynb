# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/commentdata/youtube_english_comments_Nana.csv

# %% [markdown]
# # **Importing Libraries**

# %%
import re
try:
    import contractions
except ImportError:
    # !pip install contractions
    import contractions

from contractions import fix  # Ensure contractions library is installed

import string
import nltk
# !pip install emoji

# %% [markdown]
# # **Dataset Loading**

# %%
data = pd.read_csv('/kaggle/input/commentdata/youtube_english_comments_Nana.csv')  # data contains Validate Dataset
data.shape
# Out:
# (200, 1)

# %%
print(data.info())
print(data.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Comment  200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB
# None
#                                              Comment
# 0  Hope this video was helpful 😊 Do you have expe...
# 1  "What you understand well, you enunciate clear...
# 2  Wow, what a bunch of high quality, well-prepar...
# 3  Your content is by far the best I've found abo...
# 4  Clear and concise as always. My first time pok...

# %% [markdown]
# # **Preprocessing**

# %%
df= pd.DataFrame(data) # df_mix frame contains comments of multiple languages
df.shape
# Out:
# (200, 1)

# %%
df.isnull().sum()  # count the number of missing values (NaNs) in each column of a DataFrame df.
# Out:
# Comment    0
# dtype: int64

# %%
if df.isnull().values.any():   # removes rows containing missing values (NaNs) from the DataFrame (As missing value present in df, we are removing here the respective rows)
    df.dropna(inplace=True)

# %%
print("Shape: ",df.shape)   # shape of df after removing missing values rows
print("Unique: ",df.nunique())  #used to count the number of unique values in each column of a DataFrame df.
print("Info: ",df.info())  #used to get a concise summary of a DataFrame
# Out:
# Shape:  (200, 1)
# Unique:  Comment    99
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Comment  200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB
# Info:  None

# %% [markdown]
# **Removing HTML Tags**

# %%
# Function to remove HTML tags
df2= pd.DataFrame(df)
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text)

df2['Comment'] = df2['Comment'].apply(remove_html_tags)

# %% [markdown]
# **Removing URL's**

# %%
# Function to remove URLs
def remove_url(text):
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub(r'', text)
df2['Comment'] = df2['Comment'].apply(remove_url)

# %% [markdown]
# **Removing New Lines**

# %%
# Function to remove newlines
def remove_newlines(text):
    return text.replace('\n', ' ')

df2['Comment'] = df2['Comment'].apply(remove_newlines)

# %% [markdown]
# **Handling Emojis**

# %%
# !pip install emoji
# Out:
# Requirement already satisfied: emoji in /opt/conda/lib/python3.10/site-packages (2.11.0)

# %%
import emoji
import re
def convert_emojis_to_text(text):
  text = emoji.demojize(text).split(":")
  text = " ".join(text)
  text = re.sub(r'\s+', ' ', text)
  return text

df2['Comment'] = df2['Comment'].apply(convert_emojis_to_text)

# %% [markdown]
# **Handling Emoticons**

# %%
EMOTICONS = {
    u":‑\)": "Happy face smiley",
    u":\)": "Happy face smiley",
    u":-\]": "Happy face smiley",
    u":\]": "Happy face smiley",
    u":-3": "Happy face smiley",
    u":3": "Happy face smiley",
    u":->": "Happy face smiley",
    u":>": "Happy face smiley",
    u"8-\)": "Happy face smiley",
    u":o\)": "Happy face smiley",
    u":-\}": "Happy face smiley",
    u":\}": "Happy face smiley",
    u":-\)": "Happy face smiley",
    u":c\)": "Happy face smiley",
    u":\^\)": "Happy face smiley",
    u"=\]": "Happy face smiley",
    u"=\)": "Happy face smiley",
    u":‑D": "Laughing, big grin or laugh with glasses",
    u":D": "Laughing, big grin or laugh with glasses",
    u"8‑D": "Laughing, big grin or laugh with glasses",
    u"8D": "Laughing, big grin or laugh with glasses",
    u"X‑D": "Laughing, big grin or laugh with glasses",
    u"XD": "Laughing, big grin or laugh with glasses",
    u"=D": "Laughing, big grin or laugh with glasses",
    u"=3": "Laughing, big grin or laugh with glasses",
    u"B\^D": "Laughing, big grin or laugh with glasses",
    u":-\)\)": "Very happy",
    u":‑\(": "Frown, sad, andry or pouting",
    u":-\(": "Frown, sad, andry or pouting",
    u":\(": "Frown, sad, andry or pouting",
    u":‑c": "Frown, sad, andry or pouting",
    u":c": "Frown, sad, andry or pouting",
    u":‑<": "Frown, sad, andry or pouting",
    u":<": "Frown, sad, andry or pouting",
    u":‑\[": "Frown, sad, andry or pouting",
    u":\[": "Frown, sad, andry or pouting",
    u":-\|\|": "Frown, sad, andry or pouting",
    u">:\[": "Frown, sad, andry or pouting",
    u":\{": "Frown, sad, andry or pouting",
    u":@": "Frown, sad, andry or pouting",
    u">:\(": "Frown, sad, andry or pouting",
    u":'‑\(": "Crying",
    u":'\(": "Crying",
    u":'‑\)": "Tears of happiness",
    u":'\)": "Tears of happiness",
    u"D‑':": "Horror",
    u"D:<": "Disgust",
    u"D:": "Sadness",
    u"D8": "Great dismay",
    u"D;": "Great dismay",
    u"D=": "Great dismay",
    u"DX": "Great dismay",
    u":‑O": "Surprise",
    u":O": "Surprise",
    u":‑o": "Surprise",
    u":o": "Surprise",
    u":-0": "Shock",
    u"8‑0": "Yawn",
    u">:O": "Yawn",
    u":-\*": "Kiss",
    u":\*": "Kiss",
    u":X": "Kiss",
    u";‑\)": "Wink or smirk",
    u";\)": "Wink or smirk",
    u"\*-\)": "Wink or smirk",
    u"\*\)": "Wink or smirk",
    u";‑\]": "Wink or smirk",
    u";\]": "Wink or smirk",
    u";\^\)": "Wink or smirk",
    u":‑,": "Wink or smirk",
    u";D": "Wink or smirk",
    u":‑P": "Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":P": "Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"X‑P": "Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"XP": "Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑Þ": "Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":Þ": "Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":b": "Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"d:": "Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"=p": "Tongue sticking out, cheeky, playful or blowing a raspberry",
    u">:P": "Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑/": "Skeptical, annoyed, undecided, uneasy or hesitant",
    u":/": "Skeptical, annoyed, undecided, uneasy or hesitant",
    u":-[.]": "Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:[(\\\)]": "Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:/": "Skeptical, annoyed, undecided, uneasy or hesitant",
    u":[(\\\)]": "Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=/": "Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=[(\\\)]": "Skeptical, annoyed, undecided, uneasy or hesitant",
    u":L": "Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=L": "Skeptical, annoyed, undecided, uneasy or hesitant",
    u":S": "Skeptical, annoyed, undecided, uneasy or hesitant",
    u":‑\|": "Straight face",
    u":\|": "Straight face",
    u":$": "Embarrassed or blushing",
    u":‑x": "Sealed lips or wearing braces or tongue-tied",
    u":x": "Sealed lips or wearing braces or tongue-tied",
    u":‑#": "Sealed lips or wearing braces or tongue-tied",
    u":#": "Sealed lips or wearing braces or tongue-tied",
    u":‑&": "Sealed lips or wearing braces or tongue-tied",
    u":&": "Sealed lips or wearing braces or tongue-tied",
    u"O:‑\)": "Angel, saint or innocent",
    u"O:\)": "Angel, saint or innocent",
    u"0:‑3": "Angel, saint or innocent",
    u"0:3": "Angel, saint or innocent",
    u"0:‑\)": "Angel, saint or innocent",
    u"0:\)": "Angel, saint or innocent",
    u":‑b": "Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"0;\^\)": "Angel, saint or innocent",
    u">:‑\)": "Evil or devilish",
    u">:\)": "Evil or devilish",
    u"\}:‑\)": "Evil or devilish",
    u"\}:\)": "Evil or devilish",
    u"3:‑\)": "Evil or devilish",
    u"3:\)": "Evil or devilish",
    u">;\)": "Evil or devilish",
    u"\|;‑\)": "Cool",
    u"\|‑O": "Bored",
    u":‑J": "Tongue-in-cheek",
    u"#‑\)": "Party all night",
    u"%‑\)": "Drunk or confused",
    u"%\)": "Drunk or confused",
    u":-###..": "Being sick",
    u":###..": "Being sick",
    u"<:‑\|": "Dump",
    u"\(>_<\)": "Troubled",
    u"\(>_<\)>": "Troubled",
    u"\(';'\)": "Baby",
    u"\(\^\^>``": "Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(\^_\^;\)": "Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-;\)": "Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(~_~;\) \(・\.・;\)": "Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-\)zzz": "Sleeping",
    u"\(\^_-\)": "Wink",
    u"\(\(\+_\+\)\)": "Confused",
    u"\(\+o\+\)": "Confused",
    u"\(o\|o\)": "Ultraman",
    u"\^_\^": "Joyful",
    u"\(\^_\^\)/": "Joyful",
    u"\(\^O\^\)／": "Joyful",
    u"\(\^o\^\)／": "Joyful",
    u"\(__\)": "Kowtow as a sign of respect, or dogeza for apology",
    u"_\(\._\.\)_": "Kowtow as a sign of respect, or dogeza for apology",
    u"<\(_ _\)>": "Kowtow as a sign of respect, or dogeza for apology",
    u"<m\(__\)m>": "Kowtow as a sign of respect, or dogeza for apology",
    u"m\(__\)m": "Kowtow as a sign of respect, or dogeza for apology",
    u"m\(_ _\)m": "Kowtow as a sign of respect, or dogeza for apology",
    u"\('_'\)": "Sad or Crying",
    u"\(/_;\)": "Sad or Crying",
    u"\(T_T\) \(;_;\)": "Sad or Crying",
    u"\(;_;": "Sad of Crying",
    u"\(;_:\)": "Sad or Crying",
    u"\(;O;\)": "Sad or Crying",
    u"\(:_;\)": "Sad or Crying",
    u"\(ToT\)": "Sad or Crying",
    u";_;": "Sad or Crying",
    u";-;": "Sad or Crying",
    u";n;": "Sad or Crying",
    u";;": "Sad or Crying",
    u"Q\.Q": "Sad or Crying",
    u"T\.T": "Sad or Crying",
    u"QQ": "Sad or Crying",
    u"Q_Q": "Sad or Crying",
    u"\(-\.-\)": "Shame",
    u"\(-_-\)": "Shame",
    u"\(一一\)": "Shame",
    u"\(；一_一\)": "Shame",
    u"\(=_=\)": "Tired",
    u"\(=\^\·\^=\)": "cat",
    u"\(=\^\·\·\^=\)": "cat",
    u"=_\^=	": "cat",
    u"\(\.\.\)": "Looking down",
    u"\(\._\.\)": "Looking down",
    u"\^m\^": "Giggling with hand covering mouth",
    u"\(\・\・?": "Confusion",
    u"\(?_?\)": "Confusion",
    u">\^_\^<": "Normal Laugh",
    u"<\^!\^>": "Normal Laugh",
    u"\^/\^": "Normal Laugh",
    u"\（\*\^_\^\*）": "Normal Laugh",
    u"\(\^<\^\) \(\^\.\^\)": "Normal Laugh",
    u"\(^\^\)": "Normal Laugh",
    u"\(\^\.\^\)": "Normal Laugh",
    u"\(\^_\^\.\)": "Normal Laugh",
    u"\(\^_\^\)": "Normal Laugh",
    u"\(\^\^\)": "Normal Laugh",
    u"\(\^J\^\)": "Normal Laugh",
    u"\(\*\^\.\^\*\)": "Normal Laugh",
    u"\(\^—\^\）": "Normal Laugh",
    u"\(#\^\.\^#\)": "Normal Laugh",
    u"\（\^—\^\）": "Waving",
    u"\(;_;\)/~~~": "Waving",
    u"\(\^\.\^\)/~~~": "Waving",
    u"\(-_-\)/~~~ \($\·\·\)/~~~": "Waving",
    u"\(T_T\)/~~~": "Waving",
    u"\(ToT\)/~~~": "Waving",
    u"\(\*\^0\^\*\)": "Excited",
    u"\(\*_\*\)": "Amazed",
    u"\(\*_\*;": "Amazed",
    u"\(\+_\+\) \(@_@\)": "Amazed",
    u"\(\*\^\^\)v": "Laughing,Cheerful",
    u"\(\^_\^\)v": "Laughing,Cheerful",
    u"\(\(d[-_-]b\)\)": "Headphones,Listening to music",
    u'\(-"-\)': "Worried",
    u"\(ーー;\)": "Worried",
    u"\(\^0_0\^\)": "Eyeglasses",
    u"\(\＾ｖ\＾\)": "Happy",
    u"\(\＾ｕ\＾\)": "Happy",
    u"\(\^\)o\(\^\)": "Happy",
    u"\(\^O\^\)": "Happy",
    u"\(\^o\^\)": "Happy",
    u"\)\^o\^\(": "Happy",
    u":O o_O": "Surprised",
    u"o_0": "Surprised",
    u"o\.O": "Surpised",
    u"\(o\.o\)": "Surprised",
    u"oO": "Surprised",
    u"\(\*￣m￣\)": "Dissatisfied",
    u"\(‘A`\)": "Snubbed or Deflated"
}

# %%
def convert_emoticons_to_text(text):
    for emoticon, text_rep in EMOTICONS.items():
        text = re.sub(emoticon, text_rep, text)
    return text

df2['Comment'] = df2['Comment'].apply(convert_emoticons_to_text)

# %% [markdown]
# **Text Lowercasing**

# %%
df2['Comment'] = df2['Comment'].str.lower()

# %% [markdown]
# **Expanding Contractions**

# %%
# Function to expand contractions
def expand_contractions(text):
    return fix(text)
df2['Comment'] = df2['Comment'].apply(expand_contractions)
df2.head(5)
# Out:
#                                              Comment
# 0  hope this video was helpful smiling_face_with_...
# 1  "what you understand well, you enunciate clear...
# 2  wow, what a bunch of high quality, well-prepar...
# 3  your content is by far the best i have found a...
# 4  clear and concise as always. my first time pok...

# %% [markdown]
# **Removing Punctuations**

# %%
# Function to remove punctuationdf2.head(15)
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', string.punctuation))

df2['Comment'] = df2['Comment'].apply(remove_punctuation)

# %%
print(df2.head(5))
print(df2.shape)
print(df2.info())
# Out:
#                                              Comment
# 0  hope this video was helpful smilingfacewithsmi...
# 1  what you understand well you enunciate clearly...
# 2  wow what a bunch of high quality wellprepared ...
# 3  your content is by far the best i have found a...
# 4  clear and concise as always my first time poki...
# (200, 1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Comment  200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB
# None

# %% [markdown]
# # **Using Topic Modelling**

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

def cluster_comments_lda(comments, num_topics):
    # Preprocess comments
    vectorizer = CountVectorizer(max_features=1000, stop_words='english')
    X = vectorizer.fit_transform(comments)

    # Apply LDA
    lda = LatentDirichletAllocation(n_components=num_topics, random_state=42)
    lda.fit(X)

    # Get topic distributions for comments
    topic_distributions = lda.transform(X)

    # Assign each comment to the topic with the highest probability
    comment_clusters = np.argmax(topic_distributions, axis=1)

    return comment_clusters

# Example usage
comments = df2['Comment'].tolist()
num_topics = 4  # Number of topics
comment_clusters = cluster_comments_lda(comments, num_topics)
unique_labels = np.unique(comment_clusters)
print("Distinct Labels Using Topic Modelling: ", unique_labels)
# Out:
# Distinct Labels Using Topic Modelling:  [0 1 2 3]

# %%
from sklearn.metrics import silhouette_score
from sklearn.metrics.pairwise import cosine_similarity

def calculate_silhouette_score(comments, comment_clusters):
    # Convert comments to topic distributions
    vectorizer = CountVectorizer(max_features=1000, stop_words='english')
    X = vectorizer.fit_transform(comments)

    # Calculate pairwise cosine similarity between topic distributions of comments
    topic_distributions = LatentDirichletAllocation(n_components=num_topics, random_state=42).fit_transform(X)
    pairwise_similarity = cosine_similarity(topic_distributions)

    # Calculate Silhouette score
    silhouette_avg = silhouette_score(pairwise_similarity, comment_clusters)
    print(f"Silhouette Score for Topic Modelling based Clustering: {silhouette_avg}")

    return silhouette_avg

# Example usage
silhouette_avg = calculate_silhouette_score(comments, comment_clusters)
# Out:
# Silhouette Score for Topic Modelling based Clustering: 0.9243767119440074

# %%
def print_comments_in_clusters(df, clusters):
    # Iterate over unique cluster labels
    for cluster_label in np.unique(clusters):
        # If cluster_label is -1, it represents noise points
        if cluster_label == -1:
            print("Noise Points:")
            noise_indices = np.where(clusters == cluster_label)[0]
            for index in noise_indices:
                print(df['Comment'][index])
        else:
            print(f"Cluster {cluster_label}:")
            cluster_indices = np.where(clusters == cluster_label)[0]
            for index in cluster_indices:
                print(">> ",df['Comment'][index])
        print("\n")

# Example usage
print_comments_in_clusters(df2, comment_clusters)
# Out:
# Cluster 0:
# >>  wow what a bunch of high quality wellprepared education material thank you so much for your effort
# >>  outstanding overview of azure devops i learned more in this short concise and wellexplained video that i could have learned by doing a whole bunch of research myself many thanks
# >>  this is the first video of yours i have ever seen i subscribed thank you for the high quality content
# >>  hello nana  am a very big fan of you because of your teaching style  it was the video i was looking for  because now everyone is asking for azure devopsaws devops  hope you will do azure  aws devops in near future  i have watched many tutorials but none of them have quality content like yours thank you for your time and passion to teach us
# >>  amazing video i learned a lot in a very short amount of time very clear explanation thank you nana you have helped me a lot today smilingfacewithsmilingeyes
# >>  great video a lot of useful information condensed in half an hour
# >>  appreciate you are efforts plus love you are work this video was much needed because azure is gaining popularity alot this days thanks for the video
# >>  what an excellent concrete easily digestible greatly timed and tuned video stay blessed
# >>  as soon as i need this information i see this guide thanks a lot
# >>  awesome video congratulations i learned a lot from your video today companies are demanding that we knowunderstand devops processes and you gave us a full overview nice nice nice
# >>  thank you for this introductionoverview very clear and useful
# >>  awesome video the explanations were very clear and to the point great starting point keep up the good work
# >>  very informative video i was trying to make a presentation for the company and i am doing poc with some projects and this helps me a lot
# >>  great video with a very clear breakdown for every part thanks
# >>  pure gold whata great didactics skills congrats
# >>  maaaaan this video is totally a master piece it lasts like 38 minutes but it took me 2 hours to actually go through the whole information since it is so rich and complete now i have a better understanding of cicd cycle plus you give some great alternatives at the end thank you so very much for this great video 3
# >>  awesome video such clear presentation thank you nana
# >>  i love this woman soooooooo clear thanks a lot
# >>  great video this is exactly what i needed kudos
# >>  being excited for this one cyclone
# >>  excellent overview and slide material
# >>  great video cleared a lot of confusions
# >>  everything is clear thank you
# >>  wow what a bunch of high quality wellprepared education material thank you so much for your effort
# >>  outstanding overview of azure devops i learned more in this short concise and wellexplained video that i could have learned by doing a whole bunch of research myself many thanks
# >>  this is the first video of yours i have ever seen i subscribed thank you for the high quality content
# >>  hello nana  am a very big fan of you because of your teaching style  it was the video i was looking for  because now everyone is asking for azure devopsaws devops  hope you will do azure  aws devops in near future  i have watched many tutorials but none of them have quality content like yours thank you for your time and passion to teach us
# >>  amazing video i learned a lot in a very short amount of time very clear explanation thank you nana you have helped me a lot today smilingfacewithsmilingeyes
# >>  great video a lot of useful information condensed in half an hour
# >>  appreciate you are efforts plus love you are work this video was much needed because azure is gaining popularity alot this days thanks for the video
# >>  what an excellent concrete easily digestible greatly timed and tuned video stay blessed
# >>  as soon as i need this information i see this guide thanks a lot
# >>  awesome video congratulations i learned a lot from your video today companies are demanding that we knowunderstand devops processes and you gave us a full overview nice nice nice
# >>  thank you for this introductionoverview very clear and useful
# >>  awesome video the explanations were very clear and to the point great starting point keep up the good work
# >>  very informative video i was trying to make a presentation for the company and i am doing poc with some projects and this helps me a lot
# >>  great video with a very clear breakdown for every part thanks
# >>  pure gold whata great didactics skills congrats
# >>  maaaaan this video is totally a master piece it lasts like 38 minutes but it took me 2 hours to actually go through the whole information since it is so rich and complete now i have a better understanding of cicd cycle plus you give some great alternatives at the end thank you so very much for this great video 3
# >>  awesome video such clear presentation thank you nana
# >>  i love this woman soooooooo clear thanks a lot
# >>  great video this is exactly what i needed kudos
# >>  being excited for this one cyclone
# >>  excellent overview and slide material
# >>  great video cleared a lot of confusions
# >>  everything is clear thank you
#
#
# Cluster 1:
# >>  hope this video was helpful smilingfacewithsmilingeyes do you have experience or worked with azure devops what is your experience with any comparative platform yellowheart follow me on ig for behindthescenescontent ► greenheart become a devops engineer  6month program ► orangeheart gitlab course with k8s microservices multistage ► ▬▬▬▬▬▬ t i m e s t a m p s alarmclock ▬▬▬▬▬▬ 00 00  intro and overview 00 42  what is azure devops 03 16  azure boards 05 35  azure repos 03 16  azure boards 07 52  azure pipelines build pipeline  ciconfusion 15 09  azure artifacts 16 44  stages in azure pipelines 18 44  templates in azure pipelines 20 09  environments in azure pipelines 21 17  release pipelines cdconfusion 23 17  test plans 24 44  azure devops architecture 26 35  pricing model 26 56  service connections 29 20  comparison with other platforms 33 51  which technology to learn ▬▬▬▬▬▬ want to learn more rocket ▬▬▬▬▬▬ full python course ► full docker course ► full k8s course ► devops tools explained ► ▬▬▬▬▬▬ connect with me wavinghand ▬▬▬▬▬▬ instagram ► twitter ► linkedin ► fb group ► dev ►
# >>  your content is by far the best i have found about devops and aks i have found you keep it accessible but you are still not dumbing things down i am really grateful
# >>  such a great break down great job this definitely helped me with my personal projects
# >>  fab highly appreciated the way you touched upon each and everything on azure devops
# >>  it is best video i saw on azure devops it is complete although it says beginners but it gives glimpse of endtoend devops kudos for best in class graphics content and narration although i worked on azure devops it introduced me to all features of it it is azure devops in a nutshell
# >>  very well teaching i have not anyone teaching beautifully and in concise manner redheart redheart redheart
# >>  you are an amazing tutor foldedhandslightskintone please create one playlist tutorial on aws services cost saving strategy if possible
# >>  that was the best overview summary of a technology i have ever seen phantastic
# >>  appreciate your efforts on releasing this video and it is well explained i am working on azure devops since 2 years  i would recommend to go with azure devops itself as we find all things in one place aws is also good it also bundle everything together
# >>  such a well described content about azure devops fundamentals and i appreciate that  thank you for giving us a brief knowledge about devops your page is highly recommended thumbsup thumbsup
# >>  thank you foldedhands nana it is very informative and bootstrapper of my new learning curve please post the details of any boot camp on azure devops ready to join beamingfacewithsmilingeyes
# >>  great work nana i liked the comparison part mainly what i think is the problem with azure devops it is jack of all trades but master of none meaning every service provided by azuredevops has a competition and azuredevops would not be at the top in that comparison
# >>  looking forward to adding this specialty with my aws devops skill set
# >>  a black box uncovered thank you
# >>  hope this video was helpful smilingfacewithsmilingeyes do you have experience or worked with azure devops what is your experience with any comparative platform yellowheart follow me on ig for behindthescenescontent ► greenheart become a devops engineer  6month program ► orangeheart gitlab course with k8s microservices multistage ► ▬▬▬▬▬▬ t i m e s t a m p s alarmclock ▬▬▬▬▬▬ 00 00  intro and overview 00 42  what is azure devops 03 16  azure boards 05 35  azure repos 03 16  azure boards 07 52  azure pipelines build pipeline  ciconfusion 15 09  azure artifacts 16 44  stages in azure pipelines 18 44  templates in azure pipelines 20 09  environments in azure pipelines 21 17  release pipelines cdconfusion 23 17  test plans 24 44  azure devops architecture 26 35  pricing model 26 56  service connections 29 20  comparison with other platforms 33 51  which technology to learn ▬▬▬▬▬▬ want to learn more rocket ▬▬▬▬▬▬ full python course ► full docker course ► full k8s course ► devops tools explained ► ▬▬▬▬▬▬ connect with me wavinghand ▬▬▬▬▬▬ instagram ► twitter ► linkedin ► fb group ► dev ►
# >>  your content is by far the best i have found about devops and aks i have found you keep it accessible but you are still not dumbing things down i am really grateful
# >>  such a great break down great job this definitely helped me with my personal projects
# >>  fab highly appreciated the way you touched upon each and everything on azure devops
# >>  it is best video i saw on azure devops it is complete although it says beginners but it gives glimpse of endtoend devops kudos for best in class graphics content and narration although i worked on azure devops it introduced me to all features of it it is azure devops in a nutshell
# >>  very well teaching i have not anyone teaching beautifully and in concise manner redheart redheart redheart
# >>  you are an amazing tutor foldedhandslightskintone please create one playlist tutorial on aws services cost saving strategy if possible
# >>  that was the best overview summary of a technology i have ever seen phantastic
# >>  appreciate your efforts on releasing this video and it is well explained i am working on azure devops since 2 years  i would recommend to go with azure devops itself as we find all things in one place aws is also good it also bundle everything together
# >>  such a well described content about azure devops fundamentals and i appreciate that  thank you for giving us a brief knowledge about devops your page is highly recommended thumbsup thumbsup
# >>  thank you foldedhands nana it is very informative and bootstrapper of my new learning curve please post the details of any boot camp on azure devops ready to join beamingfacewithsmilingeyes
# >>  great work nana i liked the comparison part mainly what i think is the problem with azure devops it is jack of all trades but master of none meaning every service provided by azuredevops has a competition and azuredevops would not be at the top in that comparison
# >>  looking forward to adding this specialty with my aws devops skill set
# >>  a black box uncovered thank you
# >>  hope this video was helpful smilingfacewithsmilingeyes do you have experience or worked with azure devops what is your experience with any comparative platform yellowheart follow me on ig for behindthescenescontent ► greenheart become a devops engineer  6month program ► orangeheart gitlab course with k8s microservices multistage ► ▬▬▬▬▬▬ t i m e s t a m p s alarmclock ▬▬▬▬▬▬ 00 00  intro and overview 00 42  what is azure devops 03 16  azure boards 05 35  azure repos 03 16  azure boards 07 52  azure pipelines build pipeline  ciconfusion 15 09  azure artifacts 16 44  stages in azure pipelines 18 44  templates in azure pipelines 20 09  environments in azure pipelines 21 17  release pipelines cdconfusion 23 17  test plans 24 44  azure devops architecture 26 35  pricing model 26 56  service connections 29 20  comparison with other platforms 33 51  which technology to learn ▬▬▬▬▬▬ want to learn more rocket ▬▬▬▬▬▬ full python course ► full docker course ► full k8s course ► devops tools explained ► ▬▬▬▬▬▬ connect with me wavinghand ▬▬▬▬▬▬ instagram ► twitter ► linkedin ► fb group ► dev ►
#
#
# Cluster 2:
# >>  no words this is just a great explanation you made complex things simple
# >>  outstanding great production great content professionally delivered
# >>  one of the best tutorial videos in terms of content format commentary thank you for not using background music there are no filler statements content is crisp commentary is aptly paced slides are not overcrowded i hope other tutorial creators learn something from this
# >>  we use ado here in the california public sector agencies love a lot of the tooling and how easy it is to make and automate the sdlc of my custom python applications even wrote a custom pipeline to do a custom test and coverage report using python poetry great video
# >>  as always great professional content thank you nana
# >>  i love this tutorial you have explained every step so well thank you so much
# >>  really great tutorial for beginner everything is explained in a simple way and condensed thank you confusion
# >>  omg nana yore amazing i´ve just discovered your channel this is my first course with you i was looking something to know about azure devops and i´m in the best place learning from 0 i appreciate this free course i´m so happy and i can´t wait to learn more with you thank you from mexico
# >>  wow excellent video nana i worked with azure devops for about 2 years and you explained very well all the features and characteristics in 30 minutes in which i took all this time to learn ahahah i love this platform thanks for the content
# >>  thank you so much nana your videos are always on point
# >>  thank you so much nana you have really inspired me and this crash course really helps me understood a lot fire clappinghands raisinghands
# >>  great tutorial azure devops is the best and most mature product out there in its category others are not even close
# >>  thank you nana your tutorials are the best
# >>  great content on ado slightlysmilingface  please upload complete tutorial on azure devops so that it can easy to learn for new people like me
# >>  as usual your content is so concise and easy to understand thanks a lot
# >>  i am a non it professional who is looking to change career to it after seeing your videos i got more confidence and the method of explanation is wonderful thanks nana
# >>  how you just come to know what new i will be starting and you already have created the video some days before thanks awesome as always
# >>  finally a tutorial that makes it look like abc thank you nana
# >>  great presentation and absolute clarity thank you nana
# >>  great explanation currently taking devops training at my org and this is valuable
# >>  great tutorial  both the content and the presentation thank you
# >>  great video nana i cannot imagine how much hardwork it takes to create such great video redheart
# >>  super awesome video really helped me find my feet with ado
# >>  great tutorial thank you nana all the best
# >>  most exact channel for devops thanks nana great respect from pakistan
# >>  great content with all valid answers to devops platform appreciate your efforts
# >>  scrum is agile as are kanban and tongue sticking out cheeky playful or blowing a raspberry agile is a mindset while scrum kanban and tongue sticking out cheeky playful or blowing a raspberry are frameworks i am not sure why the tool has it differentiated like that but great work providing this his level explanation very well done
# >>  that was very well explained most helpful thank you
# >>  thanks very helpful like all waysnever disappointed technan
# >>  excellent explanation thanks alot nana hundredpoints
# >>  it is easy to understand great content
# >>  as usual very good tutorial thumbsup thumbsup
# >>  no words this is just a great explanation you made complex things simple
# >>  outstanding great production great content professionally delivered
# >>  one of the best tutorial videos in terms of content format commentary thank you for not using background music there are no filler statements content is crisp commentary is aptly paced slides are not overcrowded i hope other tutorial creators learn something from this
# >>  we use ado here in the california public sector agencies love a lot of the tooling and how easy it is to make and automate the sdlc of my custom python applications even wrote a custom pipeline to do a custom test and coverage report using python poetry great video
# >>  as always great professional content thank you nana
# >>  i love this tutorial you have explained every step so well thank you so much
# >>  really great tutorial for beginner everything is explained in a simple way and condensed thank you confusion
# >>  omg nana yore amazing i´ve just discovered your channel this is my first course with you i was looking something to know about azure devops and i´m in the best place learning from 0 i appreciate this free course i´m so happy and i can´t wait to learn more with you thank you from mexico
# >>  wow excellent video nana i worked with azure devops for about 2 years and you explained very well all the features and characteristics in 30 minutes in which i took all this time to learn ahahah i love this platform thanks for the content
# >>  thank you so much nana your videos are always on point
# >>  thank you so much nana you have really inspired me and this crash course really helps me understood a lot fire clappinghands raisinghands
# >>  great tutorial azure devops is the best and most mature product out there in its category others are not even close
# >>  thank you nana your tutorials are the best
# >>  great content on ado slightlysmilingface  please upload complete tutorial on azure devops so that it can easy to learn for new people like me
# >>  as usual your content is so concise and easy to understand thanks a lot
# >>  i am a non it professional who is looking to change career to it after seeing your videos i got more confidence and the method of explanation is wonderful thanks nana
# >>  how you just come to know what new i will be starting and you already have created the video some days before thanks awesome as always
# >>  finally a tutorial that makes it look like abc thank you nana
# >>  great presentation and absolute clarity thank you nana
# >>  great explanation currently taking devops training at my org and this is valuable
# >>  great tutorial  both the content and the presentation thank you
# >>  great video nana i cannot imagine how much hardwork it takes to create such great video redheart
# >>  super awesome video really helped me find my feet with ado
# >>  great tutorial thank you nana all the best
# >>  most exact channel for devops thanks nana great respect from pakistan
# >>  great content with all valid answers to devops platform appreciate your efforts
# >>  scrum is agile as are kanban and tongue sticking out cheeky playful or blowing a raspberry agile is a mindset while scrum kanban and tongue sticking out cheeky playful or blowing a raspberry are frameworks i am not sure why the tool has it differentiated like that but great work providing this his level explanation very well done
# >>  that was very well explained most helpful thank you
# >>  thanks very helpful like all waysnever disappointed technan
# >>  excellent explanation thanks alot nana hundredpoints
# >>  it is easy to understand great content
# >>  as usual very good tutorial thumbsup thumbsup
#
#
# Cluster 3:
# >>  what you understand well you enunciate clearly  said french author boileau and so did nana beamingfacewithsmilingeyes  keep posting jewels like this one please it does help a lot
# >>  clear and concise as always my first time poking into azure devops and this video already makes me feel like i know what i am doing thanks nana
# >>  you explained it so clearly and concisely it is a great video for learning azure devops on a basic level and anyone who already works can learn a lot about new functionalities from it thanks a lot nana
# >>  wow covered lots of details in just 30 minutes video amazing work
# >>  great video having worked with azure devops in the past this really covers most of the core functionalities thank you nana
# >>  i was going to say i wish i had seen this a week ago i had to setup a ci pipeline from azure devops to an openshift cluster and i was out of my depth but i see you posted it three days ago it was still very helpful by the way your video on kubernetes helped land me my dream job kudos to you nana
# >>  this video is brilliant thanks for an excellent explanation and overview of azure devops particularly the extra detail and comparison made with other cloud technologies
# >>  this video was such a great breakdown visually answered why we should use azure devops what it is and how to use it thank you so much for comparing to aws jenkins gitlab so many ahhah moments
# >>  thanks for this it was just the intro to ado i needed pitched at exactly the right level
# >>  i am a beginner with devops i do not code anymore but i do have a coding background in older ms technologies i found this video very informative and interesting thank you for sharing this knowledge confusion
# >>  i was waiting for this if you plan to make a more detailed course please let me know thank you so much nana smilingfacewithhearts
# >>  excellent explanation in short video you covered all i started working an azure devops recently it is very useful for me
# >>  fantastic your explanation is so good that complex things become easy is it possible to make videos of microservices in azure it would be great confusion thank you
# >>  i am completely surprised by the quality of this video you are just amazing at explaining all the main concepts of azure devops
# >>  thank you very much nana for sharing this crystal clear information about the azure devops i really appreciate your efforts
# >>  fantastic your explanation is so good that complex things become easy keep it up
# >>  wow we are migrating to azure devops right now from jira jenkins and bitbucket so this is exactly what i needed just a simple over view to get my head wrapped around what is going on
# >>  i am about to interview for a company looking for azure devops engineer this helped me clear a lot of questions thank you nana
# >>  thank you very much  whenever i wanted anything in devops i come here  you the reference book in devops and cloud for me  thank you so much 3
# >>  this helped me for my next interview thanks
# >>  finally i would been waiting this video for a long time thanks
# >>  you nailed it in very short time about overview of azure devops any plans to make another video with simple app deployment like you did for gitlab ie defining app code and pipeline code if you can accommodate need your help in doing that i use azure devops but no clarity on end to end flow
# >>  thanks a lot nana really it will help us a lot no words for your work just awaiting for next video
# >>  thanks for the video watched this to understand azure devops from aws background and it helped me a lot i understand that this is for beginners but in modern software development containers are not the only artifact type we deploy for example with cloud native functions we are not deploying containers also the comparison between azure devops and aws was inaccurate based on what i learnt from your video i would compare azure devops to aws code services which contains source code  artifact repository codecommit codeartifactconfusion deployment pipeline codepipelineconfusion build tool codebuildconfusion and deployment tools codedeployconfusion anyways i am happy that i watched this and learnt a lot confusion
# >>  you have earned my sub amazing content keep going nana
# >>  thanks so clearly and nicely explained
# >>  such a great video thanks for it cheers from brazil
# >>  hey amazing video i am so interested on the devops bootcamp however i have certain questions about that for you 1 what schedule do yo have for the bootcamp 2 the bootcamp includes pair programming with you or other students 3 do you provide workbooks or any material that we can keep after the bootcamp 4 since all the it techs and procs evolve continuously have you any blog for updates in the techs and procs we learn in the bootcamp tyvm for answering those questions
# >>  this is great am new to azure devops and all looks easy now
# >>  very good and detailed information thank you
# >>  what you understand well you enunciate clearly  said french author boileau and so did nana beamingfacewithsmilingeyes  keep posting jewels like this one please it does help a lot
# >>  clear and concise as always my first time poking into azure devops and this video already makes me feel like i know what i am doing thanks nana
# >>  you explained it so clearly and concisely it is a great video for learning azure devops on a basic level and anyone who already works can learn a lot about new functionalities from it thanks a lot nana
# >>  wow covered lots of details in just 30 minutes video amazing work
# >>  great video having worked with azure devops in the past this really covers most of the core functionalities thank you nana
# >>  i was going to say i wish i had seen this a week ago i had to setup a ci pipeline from azure devops to an openshift cluster and i was out of my depth but i see you posted it three days ago it was still very helpful by the way your video on kubernetes helped land me my dream job kudos to you nana
# >>  this video is brilliant thanks for an excellent explanation and overview of azure devops particularly the extra detail and comparison made with other cloud technologies
# >>  this video was such a great breakdown visually answered why we should use azure devops what it is and how to use it thank you so much for comparing to aws jenkins gitlab so many ahhah moments
# >>  thanks for this it was just the intro to ado i needed pitched at exactly the right level
# >>  i am a beginner with devops i do not code anymore but i do have a coding background in older ms technologies i found this video very informative and interesting thank you for sharing this knowledge confusion
# >>  i was waiting for this if you plan to make a more detailed course please let me know thank you so much nana smilingfacewithhearts
# >>  excellent explanation in short video you covered all i started working an azure devops recently it is very useful for me
# >>  fantastic your explanation is so good that complex things become easy is it possible to make videos of microservices in azure it would be great confusion thank you
# >>  i am completely surprised by the quality of this video you are just amazing at explaining all the main concepts of azure devops
# >>  thank you very much nana for sharing this crystal clear information about the azure devops i really appreciate your efforts
# >>  fantastic your explanation is so good that complex things become easy keep it up
# >>  wow we are migrating to azure devops right now from jira jenkins and bitbucket so this is exactly what i needed just a simple over view to get my head wrapped around what is going on
# >>  i am about to interview for a company looking for azure devops engineer this helped me clear a lot of questions thank you nana
# >>  thank you very much  whenever i wanted anything in devops i come here  you the reference book in devops and cloud for me  thank you so much 3
# >>  this helped me for my next interview thanks
# >>  finally i would been waiting this video for a long time thanks
# >>  you nailed it in very short time about overview of azure devops any plans to make another video with simple app deployment like you did for gitlab ie defining app code and pipeline code if you can accommodate need your help in doing that i use azure devops but no clarity on end to end flow
# >>  thanks a lot nana really it will help us a lot no words for your work just awaiting for next video
# >>  thanks for the video watched this to understand azure devops from aws background and it helped me a lot i understand that this is for beginners but in modern software development containers are not the only artifact type we deploy for example with cloud native functions we are not deploying containers also the comparison between azure devops and aws was inaccurate based on what i learnt from your video i would compare azure devops to aws code services which contains source code  artifact repository codecommit codeartifactconfusion deployment pipeline codepipelineconfusion build tool codebuildconfusion and deployment tools codedeployconfusion anyways i am happy that i watched this and learnt a lot confusion
# >>  you have earned my sub amazing content keep going nana
# >>  thanks so clearly and nicely explained
# >>  such a great video thanks for it cheers from brazil
# >>  hey amazing video i am so interested on the devops bootcamp however i have certain questions about that for you 1 what schedule do yo have for the bootcamp 2 the bootcamp includes pair programming with you or other students 3 do you provide workbooks or any material that we can keep after the bootcamp 4 since all the it techs and procs evolve continuously have you any blog for updates in the techs and procs we learn in the bootcamp tyvm for answering those questions
# >>  this is great am new to azure devops and all looks easy now
# >>  very good and detailed information thank you
# >>  what you understand well you enunciate clearly  said french author boileau and so did nana beamingfacewithsmilingeyes  keep posting jewels like this one please it does help a lot

# %% [markdown]
# # **Summarization Using BART Model**

# %%
import torch

# %%
# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
import numpy as np
from transformers import BartForConditionalGeneration, BartTokenizer

# Function to generate a summary for a given text using BART
def generate_bart_summary(text):
    # Load tokenizer
    tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")

    # Load model
    model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")
    # Move model to GPU if available
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)

    # Tokenize the text
    inputs = tokenizer(text, return_tensors="pt", max_length=1024, truncation=True, padding="longest")
    inputs.to(device)

    try:
       # Estimate token length of the transcript
        token_length = inputs.input_ids.size(1)
        max_summary_length = token_length // 2  # Set summary length to half of the estimated token length
        # print("MAX_S_L: ",max_summary_length)

        summary_ids = model.generate(inputs.input_ids, max_length=max_summary_length, num_beams=4, early_stopping=True, min_length=10)

        # Decode and return the summary
        summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    except Exception as e:
        print(f"Error processing text: {e}")
        summary = ""

    return summary

# Function to break down text into smaller chunks
def chunk_text(text, chunk_size=2048):
    chunks = [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]
    return chunks

# Function to generate summaries for each cluster and concatenate them
def summarize_clusters(df, clusters):
    # Initialize an empty list to store summaries of each cluster
    cluster_summaries = []

    # Iterate over unique cluster labels
    for cluster_label in np.unique(clusters):
        # Get comments belonging to the current cluster
        if cluster_label == -1:
            cluster_comments = df.loc[clusters == cluster_label, 'Comment'].tolist()
        else:
            cluster_comments = df.loc[clusters == cluster_label, 'Comment'].tolist()

        # Concatenate comments into a single string
        cluster_text = ' '.join(cluster_comments)

        # Chunk the cluster text into smaller parts
        text_chunks = chunk_text(cluster_text)

        # Generate summary for each chunk and concatenate them
        chunk_summaries = [generate_bart_summary(chunk) for chunk in text_chunks]
        cluster_summary = ' '.join(chunk_summaries)

        # Append the summary to the list of summaries
        cluster_summaries.append(cluster_summary)

    # Concatenate summaries of all clusters
    all_clusters_summary = ' '.join(cluster_summaries)

    return all_clusters_summary

# Example usage
summary = summarize_clusters(df2, comment_clusters)
print(summary)
# Out:
# wow what a bunch of high quality wellprepared education material thank you so much for your effort outstanding overview of azure devops. i learned more in this short concise and wellexplained video that i could have learned by doing a whole bunch of research myself. this is the first video of yours i have ever seen i subscribed thank you for the high quality content. "This is exactly what i needed kudos being excited for this one cyclone  excellent overview and slide material great video cleared a lot of confusions everything is clear" "I learned more in this short concise and wellexplained video that i could have learned by doing a whole bunch of research myself many thanks this is the first video of yours i have ever seen i subscribed" resentation for the company and i am doing poc with some projects and this helps me a lot great video with a very clear breakdown for every part thanks pure gold whata great didactics skills.  azure devops in a nutshell very well teaching i have not anyone teaching beautifully and in concise manner you are an amazing tutor foldedhandslightskintone please create one playlist tutorial on aws services cost saving strategy if possible that was the best overview summary of a technology i have ever seen phantastic appreciate  your content is by far the best i have found about devops and aks. your efforts on releasing this video and it is well explained i am working on azure devops since 2 years  i would recommend to go with azured devops itself as we find all things in one place aws is also good it also bundle everything together such a well described content about devops fundamentals and i appreciate that. The best video i saw on azure devops it is complete although it says beginners but it gives glimpse of endtoend devops kudos for best in class graphics content and narration. Please create one playlist tutorial on aws services cost saving strategy if possible. xperience or worked with azure devops what is your experience with any comparative platform yellowheart follow me on ig for behindthescenescontent. greenheart become a devops engineer  6month program. orangeheart gitlab course with k8s microservices multistage. no words this is just a great explanation you made complex things simple outstanding great production great content professionally delivered one of the best tutorial videos in terms of content format commentary thank you for not using background music. Great content with all valid answers to devops platform appreciate your efforts scrum is agile as are kanban and tongue sticking out cheeky playful or blowing a raspberry. Great work providing this his level explanation very well done that was very well explained. custom pipeline to do a custom test and coverage report using python poetry great video as always great professional content thank you nana i love this tutorial you have explained every step so well thank you so much really great tutorial for beginner. o create such great video redheart  super awesome video really helped me find my feet with ado great tutorial thank you nana all the best most exact channel for devops thanks nana. Nana beamingfacewithsmilingeyes explains azure devops so clearly and concisely. Anyone who already works can learn a lot about new functionalities from it. Nana explains all the main concepts of azure devops in this video. The video is a reference book in devops and cloud for me. This video is a great video for learning azure devops on a basic level and anyone who already works can learn a lot about new functionalities from it thanks a lot nana wow covered lots of details in just 30 minutes video amazing work  great video. "I am completely surprised by the quality of this video" "You are just amazing at explaining all the main concepts of azure devops" "It will help us a lot no words for your work just awaiting for next video" ideo watched this to understand azure devops from aws background and it helped me a lot i understand that this is for beginne ...
